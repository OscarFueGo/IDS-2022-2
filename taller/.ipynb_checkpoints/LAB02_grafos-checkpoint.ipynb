# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1-5X9OUkA-C2Ih1gOS9Jd7GmkTWUEpDg1)
#
# Asignatura: Introducción a Data Science
#
# Profesor: Juan Bekios Calfa
#
# ---
#
#
#
# # Laboratorio 02: Teoría de grafos
#
# En los cursos de ciencias básicas de computación se estudia con frecuencia el problema del vendedor viajero (problema del vendedor ambulante, problema del agente viajero o problema del viajante (**TSP** por sus siglas en inglés, *Travelling Salesman Problem*) y se definen como: dada una lista de ciudades y las distancias entre cada par de ellas, ¿cuál es la ruta más corta posible que visita cada ciudad exactamente una vez y al finalizar regresa a la ciudad origen? Este es un problema NP-Hard dentro en la optimización combinatoria, muy importante en investigación operativa y en ciencias de la computación. [wikipedia](https://es.wikipedia.org/wiki/Problema_del_viajante)
#
# También, existe otro tipo de problemas interesantes y similares al del vendedor viajero. Uno de ellos, es el que implementaremos en este laboratorio, denominado problema del cartero chino (PCC). El problema consiste en **encontrar el camino más corto o circuito cerrado**, que **visite cada arista de un grafo (conectado) no direccionado**, o sea, que pase al menos una vez por cada arista del grafo, volviendo al punto (o nodo) de partida. Cuando el grafo posee un circuito euleriano (un paseo cerrado que alcance toda arista solamente una vez), ese circuito es una solución óptima. [wikipedia](https://es.wikipedia.org/wiki/Problema_del_cartero_chino)
#
# **Problema**:
#
# El parque Sleeping Giant State, ubicado en  New Haven, Connecticut, Estados Unidos. Es un parque compuesto de un sin número de senderos que permiten a los turistas caminar por ellos. Como el parque tiene una extensión de terreno muy grande, mucha gente decide recorrer todos los senderos en un solo día.
#
# ![](https://www.wnpr.org/sites/wnpr/files/styles/x_large/public/201906/sleeping__3_of_5_.jpg)
#
# Como el calcular la ruta adecuada no es fácil recurriremos al material visto en clases para poder encontrar la ruta óptima que nos permita recorrer todos los senderos en un mínimo de tiempo.
#
# Para poder resolver este problema contamos con un plano que indica cada una de esas rutas.
#
# ![](https://giantstout.files.wordpress.com/2010/10/sg-trail-map.jpg?w=640&h=460)
#
# El problema está basado en [link](https://www.datacamp.com/community/tutorials/networkx-python-graph-tutorial).
#
# ## Librerías que se utilzarán en el laboratorio

# %%
import networkx as nx # Librería para grafos
import pandas as pd # Librería para manejar datos (dataframe)
import matplotlib.pyplot as plt # Librería para gráficos

# %% [markdown]
# ## 1. Carga de datos
#
# Para resolver este problema cargaremos un archivo que contiene una lista de con los arcos del grafo y cada fila contiene los siguientes campos:
#
# *   **node1** y **node2**: Nombre de los nodos conectados.
# *   **trail**: Atributo que indica un atributo del arco. (Por ejemplo, rs=cuadro rojo)
# *   **distance**: Atributo del arco que indica la longitud del sendero en millas.
# *   **color**: Color utilizado para indicar el sendero trazado.
# *   **estimate**: Distancia del arco estimada a partir de la observación de los senderos del mapa (1=SI, 0=N=), ya que algunas distancias no se proporcionan. Esto es solo de referencia y no será utilizado para el análisis.

# %%
# Grab edge list data hosted on Gist
lista_arcos = pd.read_csv('https://gist.githubusercontent.com/brooksandrew/e570c38bcc72a8d102422f2af836513b/raw/89c76b2563dbc0e88384719a35cba0dfc04cd522/edgelist_sleeping_giant.csv')

lista_arcos.head(10)
# Out:
#           node1         node2 trail  distance color  estimate
# 0  rs_end_north          v_rs    rs      0.30   red         0
# 1          v_rs          b_rs    rs      0.21   red         0
# 2          b_rs          g_rs    rs      0.11   red         0
# 3          g_rs          w_rs    rs      0.18   red         0
# 4          w_rs          o_rs    rs      0.21   red         0
# 5          o_rs          y_rs    rs      0.12   red         0
# 6          y_rs  rs_end_south    rs      0.39   red         0
# 7  rc_end_north          v_rc    rc      0.70   red         0
# 8          v_rc          b_rc    rc      0.04   red         0
# 9          b_rc          g_rc    rc      0.15   red         0

# %% [markdown]
# ### Lista de nodos
#
# Las listas de nodos suelen ser opcionales en `networkx`, y otras bibliotecas de gráficos, cuando se proporcionan listas de arcos ya vienen los nombres por lo que no es necesario identificarlos. Sin embargo, en este caso, hay algunos atributos de nodo que nos gustaría añadir: Coordenadas X, Y de los nodos (intersecciones de senderos) para que pueda trazar su gráfica con el mismo diseño que el mapa de senderos.
#
# *    id: nombre del nodo correspondiente al nodo1 y al nodo2 en la lista de bordes.
# *    X: posición horizontal/coordenada del nodo correspondiente al topleft.
# *    Y: posición/coordinación vertical del nodo relativo al topleft.

# %%
# Archivo de la lista de nodos
lista_nodos = pd.read_csv('https://gist.githubusercontent.com/brooksandrew/f989e10af17fb4c85b11409fea47895b/raw/a3a8da0fa5b094f1ca9d82e1642b384889ae16e8/nodelist_sleeping_giant.csv')

lista_nodos.head(10)
# Out:
#            id     X     Y
# 0        b_bv  1486   732
# 1        b_bw   716  1357
# 2  b_end_east  3164  1111
# 3  b_end_west   141  1938
# 4         b_g  1725   771
# 5       b_gy2  2000   983
# 6         b_o  2039  1012
# 7        b_rc  1311   979
# 8        b_rd   268  1744
# 9   b_rd_dupe   268  1744

# %% [markdown]
# ## 2. Creando el grafo
#
# Usaremos la lista de arcos (aristas) y la lista de nodos para crear el grafo utilizando las librerías de `networkx`.

# %%
# Crear un grafo limpio (no digido)
g = nx.Graph()

# %% [markdown]
# Construimos el grafo ingresando cada uno de sus arcos y sus correspondientes atributos al grafo `g`.

# %%
# Agregar aristas y atributos a las aristas (arcos)

for index, datos_arco in lista_arcos.iterrows():
  #print(datos_arco)
  print(f'Indice {index}:')
  print(f'Nodo origen: {datos_arco["node1"]}')
  print(f'Nodo destino: {datos_arco["node2"]}')
  print('-'*40)
  print(datos_arco[2:].to_dict())
  print('='*40)
  g.add_edge(datos_arco["node1"], datos_arco["node2"], attr_dict=datos_arco[2:].to_dict())
# Out:
# Indice 0:
# Nodo origen: rs_end_north
# Nodo destino: v_rs
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.3, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 1:
# Nodo origen: v_rs
# Nodo destino: b_rs
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.21, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 2:
# Nodo origen: b_rs
# Nodo destino: g_rs
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.11, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 3:
# Nodo origen: g_rs
# Nodo destino: w_rs
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.18, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 4:
# Nodo origen: w_rs
# Nodo destino: o_rs
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.21, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 5:
# Nodo origen: o_rs
# Nodo destino: y_rs
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.12, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 6:
# Nodo origen: y_rs
# Nodo destino: rs_end_south
# ----------------------------------------
# {'trail': 'rs', 'distance': 0.39, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 7:
# Nodo origen: rc_end_north
# Nodo destino: v_rc
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.7, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 8:
# Nodo origen: v_rc
# Nodo destino: b_rc
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.04, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 9:
# Nodo origen: b_rc
# Nodo destino: g_rc
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.15, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 10:
# Nodo origen: g_rc
# Nodo destino: o_rc
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.13, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 11:
# Nodo origen: o_rc
# Nodo destino: w_rc
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.23, 'color': 'red', 'estimate': 1}
# ========================================
# Indice 12:
# Nodo origen: w_rc
# Nodo destino: y_rc
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.14, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 13:
# Nodo origen: y_rc
# Nodo destino: rc_end_south
# ----------------------------------------
# {'trail': 'rc', 'distance': 0.36, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 14:
# Nodo origen: rt_end_north
# Nodo destino: v_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.3, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 15:
# Nodo origen: v_rt
# Nodo destino: tt_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.16, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 16:
# Nodo origen: tt_rt
# Nodo destino: b_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.04, 'color': 'red', 'estimate': 1}
# ========================================
# Indice 17:
# Nodo origen: b_rt
# Nodo destino: g_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.09, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 18:
# Nodo origen: g_rt
# Nodo destino: o_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.05, 'color': 'red', 'estimate': 1}
# ========================================
# Indice 19:
# Nodo origen: o_rt
# Nodo destino: w_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.06, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 20:
# Nodo origen: w_rt
# Nodo destino: y_rt
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.19, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 21:
# Nodo origen: y_rt
# Nodo destino: rt_end_south
# ----------------------------------------
# {'trail': 'rt', 'distance': 0.18, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 22:
# Nodo origen: rh_end_north
# Nodo destino: v_rh
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.24, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 23:
# Nodo origen: v_rh
# Nodo destino: b_rh
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.12, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 24:
# Nodo origen: b_rh
# Nodo destino: rh_end_tt_1
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.06, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 25:
# Nodo origen: rh_end_tt_2
# Nodo destino: o_rh
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.07, 'color': 'red', 'estimate': 1}
# ========================================
# Indice 26:
# Nodo origen: o_rh
# Nodo destino: rh_end_tt_3
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.04, 'color': 'red', 'estimate': 1}
# ========================================
# Indice 27:
# Nodo origen: rh_end_tt_4
# Nodo destino: y_rh
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.09, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 28:
# Nodo origen: y_rh
# Nodo destino: rh_end_south
# ----------------------------------------
# {'trail': 'rh', 'distance': 0.06, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 29:
# Nodo origen: rd_end_north
# Nodo destino: v_rd
# ----------------------------------------
# {'trail': 'rd', 'distance': 0.14, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 30:
# Nodo origen: v_rd
# Nodo destino: b_rd
# ----------------------------------------
# {'trail': 'rd', 'distance': 0.06, 'color': 'red', 'estimate': 1}
# ========================================
# Indice 31:
# Nodo origen: b_rd
# Nodo destino: rd_end_south
# ----------------------------------------
# {'trail': 'rd', 'distance': 0.13, 'color': 'red', 'estimate': 0}
# ========================================
# Indice 32:
# Nodo origen: v_end_west
# Nodo destino: b_v
# ----------------------------------------
# {'trail': 'v', 'distance': 0.13, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 33:
# Nodo origen: b_v
# Nodo destino: v_rd
# ----------------------------------------
# {'trail': 'v', 'distance': 0.3, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 34:
# Nodo origen: v_rd
# Nodo destino: v_rh
# ----------------------------------------
# {'trail': 'v', 'distance': 0.38, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 35:
# Nodo origen: v_rh
# Nodo destino: v_rt
# ----------------------------------------
# {'trail': 'v', 'distance': 0.44, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 36:
# Nodo origen: v_rt
# Nodo destino: v_rc
# ----------------------------------------
# {'trail': 'v', 'distance': 0.5, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 37:
# Nodo origen: v_rc
# Nodo destino: v_bv
# ----------------------------------------
# {'trail': 'v', 'distance': 0.27, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 38:
# Nodo origen: v_bv
# Nodo destino: v_rs
# ----------------------------------------
# {'trail': 'v', 'distance': 0.52, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 39:
# Nodo origen: v_rs
# Nodo destino: v_end_east
# ----------------------------------------
# {'trail': 'v', 'distance': 0.54, 'color': 'violet', 'estimate': 0}
# ========================================
# Indice 40:
# Nodo origen: bstub_w
# Nodo destino: b_v
# ----------------------------------------
# {'trail': 'b', 'distance': 0.1, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 41:
# Nodo origen: b_end_west
# Nodo destino: b_v
# ----------------------------------------
# {'trail': 'b', 'distance': 0.32, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 42:
# Nodo origen: b_v
# Nodo destino: rd_end_south
# ----------------------------------------
# {'trail': 'b', 'distance': 0.04, 'color': 'blue', 'estimate': 1}
# ========================================
# Indice 43:
# Nodo origen: rd_end_south_dupe
# Nodo destino: b_rd_dupe
# ----------------------------------------
# {'trail': 'b', 'distance': 0.16, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 44:
# Nodo origen: rd_end_south
# Nodo destino: rd_end_south_dupe
# ----------------------------------------
# {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 45:
# Nodo origen: b_rd
# Nodo destino: b_rd_dupe
# ----------------------------------------
# {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 46:
# Nodo origen: b_rd
# Nodo destino: b_rh
# ----------------------------------------
# {'trail': 'b', 'distance': 0.53, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 47:
# Nodo origen: b_rh
# Nodo destino: b_tt_1
# ----------------------------------------
# {'trail': 'b', 'distance': 0.06, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 48:
# Nodo origen: b_tt_1
# Nodo destino: b_bw
# ----------------------------------------
# {'trail': 'b', 'distance': 0.18, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 49:
# Nodo origen: b_bw
# Nodo destino: b_rt
# ----------------------------------------
# {'trail': 'b', 'distance': 0.14, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 50:
# Nodo origen: b_rt
# Nodo destino: b_tt_2
# ----------------------------------------
# {'trail': 'b', 'distance': 0.03, 'color': 'blue', 'estimate': 1}
# ========================================
# Indice 51:
# Nodo origen: b_tt_2
# Nodo destino: b_tt_3
# ----------------------------------------
# {'trail': 'b', 'distance': 0.15, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 52:
# Nodo origen: b_tt_3
# Nodo destino: b_rc
# ----------------------------------------
# {'trail': 'b', 'distance': 0.4, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 53:
# Nodo origen: b_rc
# Nodo destino: b_bv
# ----------------------------------------
# {'trail': 'b', 'distance': 0.41, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 54:
# Nodo origen: b_bv
# Nodo destino: b_rs
# ----------------------------------------
# {'trail': 'b', 'distance': 0.43, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 55:
# Nodo origen: b_rs
# Nodo destino: b_g
# ----------------------------------------
# {'trail': 'b', 'distance': 0.07, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 56:
# Nodo origen: b_g
# Nodo destino: b_w
# ----------------------------------------
# {'trail': 'b', 'distance': 0.16, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 57:
# Nodo origen: b_w
# Nodo destino: b_gy2
# ----------------------------------------
# {'trail': 'b', 'distance': 0.41, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 58:
# Nodo origen: b_gy2
# Nodo destino: b_o
# ----------------------------------------
# {'trail': 'b', 'distance': 0.05, 'color': 'blue', 'estimate': 1}
# ========================================
# Indice 59:
# Nodo origen: b_o
# Nodo destino: b_y
# ----------------------------------------
# {'trail': 'b', 'distance': 0.08, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 60:
# Nodo origen: b_y
# Nodo destino: b_end_east
# ----------------------------------------
# {'trail': 'b', 'distance': 1.32, 'color': 'blue', 'estimate': 0}
# ========================================
# Indice 61:
# Nodo origen: bstub_w
# Nodo destino: w_tt
# ----------------------------------------
# {'trail': 'w', 'distance': 0.38, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 62:
# Nodo origen: w_tt
# Nodo destino: w_bw
# ----------------------------------------
# {'trail': 'w', 'distance': 0.24, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 63:
# Nodo origen: w_bw
# Nodo destino: g_w
# ----------------------------------------
# {'trail': 'w', 'distance': 0.09, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 64:
# Nodo origen: g_w
# Nodo destino: o_w_1
# ----------------------------------------
# {'trail': 'w', 'distance': 0.18, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 65:
# Nodo origen: o_w_1
# Nodo destino: w_rt
# ----------------------------------------
# {'trail': 'w', 'distance': 0.09, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 66:
# Nodo origen: w_rt
# Nodo destino: w_gy1
# ----------------------------------------
# {'trail': 'w', 'distance': 0.33, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 67:
# Nodo origen: w_gy1
# Nodo destino: w_rc
# ----------------------------------------
# {'trail': 'w', 'distance': 0.33, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 68:
# Nodo origen: w_rc
# Nodo destino: o_w_2
# ----------------------------------------
# {'trail': 'w', 'distance': 0.23, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 69:
# Nodo origen: o_w_2
# Nodo destino: w_rs
# ----------------------------------------
# {'trail': 'w', 'distance': 0.26, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 70:
# Nodo origen: w_rs
# Nodo destino: b_w
# ----------------------------------------
# {'trail': 'w', 'distance': 0.06, 'color': 'gray', 'estimate': 1}
# ========================================
# Indice 71:
# Nodo origen: b_w
# Nodo destino: w_gy2
# ----------------------------------------
# {'trail': 'w', 'distance': 0.42, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 72:
# Nodo origen: w_gy2
# Nodo destino: park_east
# ----------------------------------------
# {'trail': 'w', 'distance': 0.12, 'color': 'gray', 'estimate': 0}
# ========================================
# Indice 73:
# Nodo origen: g_w
# Nodo destino: g_rt
# ----------------------------------------
# {'trail': 'g', 'distance': 0.31, 'color': 'green', 'estimate': 0}
# ========================================
# Indice 74:
# Nodo origen: g_rt
# Nodo destino: g_gy1
# ----------------------------------------
# {'trail': 'g', 'distance': 0.26, 'color': 'green', 'estimate': 0}
# ========================================
# Indice 75:
# Nodo origen: g_gy1
# Nodo destino: g_rc
# ----------------------------------------
# {'trail': 'g', 'distance': 0.37, 'color': 'green', 'estimate': 0}
# ========================================
# Indice 76:
# Nodo origen: g_rc
# Nodo destino: g_rs
# ----------------------------------------
# {'trail': 'g', 'distance': 0.45, 'color': 'green', 'estimate': 0}
# ========================================
# Indice 77:
# Nodo origen: g_rs
# Nodo destino: b_g
# ----------------------------------------
# {'trail': 'g', 'distance': 0.05, 'color': 'green', 'estimate': 1}
# ========================================
# Indice 78:
# Nodo origen: b_g
# Nodo destino: g_gy2
# ----------------------------------------
# {'trail': 'g', 'distance': 0.45, 'color': 'green', 'estimate': 0}
# ========================================
# Indice 79:
# Nodo origen: g_gy2
# Nodo destino: park_east
# ----------------------------------------
# {'trail': 'g', 'distance': 0.14, 'color': 'green', 'estimate': 0}
# ========================================
# Indice 80:
# Nodo origen: o_y_tt_end_west
# Nodo destino: o_rh
# ----------------------------------------
# {'trail': 'o', 'distance': 0.32, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 81:
# Nodo origen: o_rh
# Nodo destino: o_tt
# ----------------------------------------
# {'trail': 'o', 'distance': 0.08, 'color': 'orange', 'estimate': 1}
# ========================================
# Indice 82:
# Nodo origen: o_tt
# Nodo destino: o_w_1
# ----------------------------------------
# {'trail': 'o', 'distance': 0.27, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 83:
# Nodo origen: o_w_1
# Nodo destino: o_rt
# ----------------------------------------
# {'trail': 'o', 'distance': 0.13, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 84:
# Nodo origen: o_w_1
# Nodo destino: o_gy1
# ----------------------------------------
# {'trail': 'o', 'distance': 0.24, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 85:
# Nodo origen: o_gy1
# Nodo destino: o_rc
# ----------------------------------------
# {'trail': 'o', 'distance': 0.58, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 86:
# Nodo origen: o_rc
# Nodo destino: o_w_2
# ----------------------------------------
# {'trail': 'o', 'distance': 0.11, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 87:
# Nodo origen: o_w_2
# Nodo destino: o_rs
# ----------------------------------------
# {'trail': 'o', 'distance': 0.15, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 88:
# Nodo origen: o_rs
# Nodo destino: o_gy2
# ----------------------------------------
# {'trail': 'o', 'distance': 0.33, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 89:
# Nodo origen: o_gy2
# Nodo destino: b_o
# ----------------------------------------
# {'trail': 'o', 'distance': 0.06, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 90:
# Nodo origen: b_o
# Nodo destino: park_east
# ----------------------------------------
# {'trail': 'o', 'distance': 0.11, 'color': 'orange', 'estimate': 0}
# ========================================
# Indice 91:
# Nodo origen: o_y_tt_end_west
# Nodo destino: y_rh
# ----------------------------------------
# {'trail': 'y', 'distance': 0.26, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 92:
# Nodo origen: y_rh
# Nodo destino: y_rt
# ----------------------------------------
# {'trail': 'y', 'distance': 0.32, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 93:
# Nodo origen: y_rt
# Nodo destino: y_gy1
# ----------------------------------------
# {'trail': 'y', 'distance': 0.31, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 94:
# Nodo origen: y_gy1
# Nodo destino: y_rc
# ----------------------------------------
# {'trail': 'y', 'distance': 0.18, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 95:
# Nodo origen: y_rc
# Nodo destino: y_rs
# ----------------------------------------
# {'trail': 'y', 'distance': 0.53, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 96:
# Nodo origen: y_rs
# Nodo destino: y_gy2
# ----------------------------------------
# {'trail': 'y', 'distance': 0.16, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 97:
# Nodo origen: y_gy2
# Nodo destino: b_y
# ----------------------------------------
# {'trail': 'y', 'distance': 0.28, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 98:
# Nodo origen: b_y
# Nodo destino: park_east
# ----------------------------------------
# {'trail': 'y', 'distance': 0.14, 'color': 'yellow', 'estimate': 0}
# ========================================
# Indice 99:
# Nodo origen: o_y_tt_end_west
# Nodo destino: nature_end_west
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.16, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 100:
# Nodo origen: nature_end_west
# Nodo destino: rh_end_tt_4
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.2, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 101:
# Nodo origen: rh_end_tt_4
# Nodo destino: rh_end_tt_3
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.15, 'color': 'black', 'estimate': 1}
# ========================================
# Indice 102:
# Nodo origen: rh_end_tt_3
# Nodo destino: o_tt
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.11, 'color': 'black', 'estimate': 1}
# ========================================
# Indice 103:
# Nodo origen: o_tt
# Nodo destino: rh_end_tt_2
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.13, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 104:
# Nodo origen: rh_end_tt_2
# Nodo destino: w_tt
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.06, 'color': 'black', 'estimate': 1}
# ========================================
# Indice 105:
# Nodo origen: w_tt
# Nodo destino: rh_end_tt_1
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.08, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 106:
# Nodo origen: rh_end_tt_1
# Nodo destino: b_tt_1
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.03, 'color': 'black', 'estimate': 1}
# ========================================
# Indice 107:
# Nodo origen: b_tt_1
# Nodo destino: tt_rt
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.36, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 108:
# Nodo origen: tt_rt
# Nodo destino: b_tt_2
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.06, 'color': 'black', 'estimate': 1}
# ========================================
# Indice 109:
# Nodo origen: b_tt_2_dupe
# Nodo destino: b_tt_3_dupe
# ----------------------------------------
# {'trail': 'tt', 'distance': 0.18, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 110:
# Nodo origen: b_tt_3
# Nodo destino: b_tt_3_dupe
# ----------------------------------------
# {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 111:
# Nodo origen: b_tt_2
# Nodo destino: b_tt_2_dupe
# ----------------------------------------
# {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# ========================================
# Indice 112:
# Nodo origen: nature_end_west
# Nodo destino: y_rh
# ----------------------------------------
# {'trail': 'nature', 'distance': 0.11, 'color': 'forestgreen', 'estimate': 0}
# ========================================
# Indice 113:
# Nodo origen: o_tt
# Nodo destino: y_rt
# ----------------------------------------
# {'trail': 'nature', 'distance': 0.35, 'color': 'forestgreen', 'estimate': 0}
# ========================================
# Indice 114:
# Nodo origen: b_bw
# Nodo destino: w_bw
# ----------------------------------------
# {'trail': 'bw', 'distance': 0.19, 'color': 'lightblue', 'estimate': 0}
# ========================================
# Indice 115:
# Nodo origen: g_gy1
# Nodo destino: o_gy1
# ----------------------------------------
# {'trail': 'gy1', 'distance': 0.15, 'color': 'yellowgreen', 'estimate': 0}
# ========================================
# Indice 116:
# Nodo origen: o_gy1
# Nodo destino: w_gy1
# ----------------------------------------
# {'trail': 'gy1', 'distance': 0.16, 'color': 'yellowgreen', 'estimate': 0}
# ========================================
# Indice 117:
# Nodo origen: w_gy1
# Nodo destino: y_gy1
# ----------------------------------------
# {'trail': 'gy1', 'distance': 0.14, 'color': 'yellowgreen', 'estimate': 0}
# ========================================
# Indice 118:
# Nodo origen: v_bv
# Nodo destino: b_bv
# ----------------------------------------
# {'trail': 'bv', 'distance': 0.08, 'color': 'purple', 'estimate': 0}
# ========================================
# Indice 119:
# Nodo origen: g_gy2
# Nodo destino: w_gy2
# ----------------------------------------
# {'trail': 'gy2', 'distance': 0.05, 'color': 'yellowgreen', 'estimate': 0}
# ========================================
# Indice 120:
# Nodo origen: w_gy2
# Nodo destino: b_gy2
# ----------------------------------------
# {'trail': 'gy2', 'distance': 0.03, 'color': 'yellowgreen', 'estimate': 1}
# ========================================
# Indice 121:
# Nodo origen: b_gy2
# Nodo destino: o_gy2
# ----------------------------------------
# {'trail': 'gy2', 'distance': 0.07, 'color': 'yellowgreen', 'estimate': 0}
# ========================================
# Indice 122:
# Nodo origen: o_gy2
# Nodo destino: y_gy2
# ----------------------------------------
# {'trail': 'gy2', 'distance': 0.12, 'color': 'yellowgreen', 'estimate': 0}
# ========================================

# %% [markdown]
# Para ilustrar los valores devueltos revisamos la última fila examinada en el ciclo `for`.

# %%
# Ejemplo de lista de arcos
print(datos_arco[0]) # nodo 1
print(datos_arco[1]) # nodo 2
print(datos_arco[2:].to_dict()) # atributos asociados al arco
# Out:
# o_gy2
# y_gy2
# {'trail': 'gy2', 'distance': 0.12, 'color': 'yellowgreen', 'estimate': 0}

# %% [markdown]
# De la misma forma que se agregaron atributos a los arcos del grafo. Agregaremos los atributos a cada nodo.

# %%
# Agregar atributos a los nodos
for _, fila_nodo in lista_nodos.iterrows():
  print(fila_nodo['id'], fila_nodo[1:].to_dict())
  g.nodes[fila_nodo['id']].update(fila_nodo[1:].to_dict())
# Out:
# b_bv {'X': 1486, 'Y': 732}
# b_bw {'X': 716, 'Y': 1357}
# b_end_east {'X': 3164, 'Y': 1111}
# b_end_west {'X': 141, 'Y': 1938}
# b_g {'X': 1725, 'Y': 771}
# b_gy2 {'X': 2000, 'Y': 983}
# b_o {'X': 2039, 'Y': 1012}
# b_rc {'X': 1311, 'Y': 979}
# b_rd {'X': 268, 'Y': 1744}
# b_rd_dupe {'X': 268, 'Y': 1744}
# b_rh {'X': 525, 'Y': 1380}
# b_rs {'X': 1747, 'Y': 700}
# b_rt {'X': 835, 'Y': 1309}
# b_tt_1 {'X': 571, 'Y': 1418}
# b_tt_2 {'X': 857, 'Y': 1287}
# b_tt_2_dupe {'X': 857, 'Y': 1287}
# b_tt_3 {'X': 1006, 'Y': 1206}
# b_tt_3_dupe {'X': 1006, 'Y': 1206}
# b_v {'X': 285, 'Y': 1937}
# b_w {'X': 1691, 'Y': 940}
# b_y {'X': 2134, 'Y': 1078}
# bstub_w {'X': 372, 'Y': 1845}
# g_gy1 {'X': 1098, 'Y': 1183}
# g_gy2 {'X': 1976, 'Y': 906}
# g_rc {'X': 1451, 'Y': 1020}
# g_rs {'X': 1676, 'Y': 775}
# g_rt {'X': 908, 'Y': 1378}
# g_w {'X': 700, 'Y': 1582}
# nature_end_west {'X': 600, 'Y': 1861}
# o_gy1 {'X': 1130, 'Y': 1297}
# o_gy2 {'X': 1994, 'Y': 1059}
# o_rc {'X': 1498, 'Y': 1153}
# o_rh {'X': 585, 'Y': 1674}
# o_rs {'X': 1724, 'Y': 1148}
# o_rt {'X': 927, 'Y': 1427}
# o_tt {'X': 665, 'Y': 1690}
# o_w_1 {'X': 850, 'Y': 1490}
# o_w_2 {'X': 1600, 'Y': 1176}
# o_y_tt_end_west {'X': 459, 'Y': 1924}
# park_east {'X': 2131, 'Y': 921}
# rc_end_north {'X': 867, 'Y': 618}
# rc_end_south {'X': 1450, 'Y': 1800}
# rd_end_north {'X': 185, 'Y': 1561}
# rd_end_south {'X': 273, 'Y': 1869}
# rd_end_south_dupe {'X': 273, 'Y': 1869}
# rh_end_north {'X': 205, 'Y': 1472}
# rh_end_south {'X': 721, 'Y': 1925}
# rh_end_tt_1 {'X': 558, 'Y': 1430}
# rh_end_tt_2 {'X': 550, 'Y': 1608}
# rh_end_tt_3 {'X': 573, 'Y': 1707}
# rh_end_tt_4 {'X': 695, 'Y': 1767}
# rs_end_north {'X': 1772, 'Y': 172}
# rs_end_south {'X': 1865, 'Y': 1598}
# rt_end_north {'X': 681, 'Y': 850}
# rt_end_south {'X': 944, 'Y': 1837}
# tt_rt {'X': 833, 'Y': 1273}
# v_bv {'X': 1425, 'Y': 691}
# v_end_east {'X': 2131, 'Y': 921}
# v_end_west {'X': 359, 'Y': 1976}
# v_rc {'X': 1288, 'Y': 934}
# v_rd {'X': 258, 'Y': 1684}
# v_rh {'X': 415, 'Y': 1350}
# v_rs {'X': 1793, 'Y': 484}
# v_rt {'X': 802, 'Y': 1115}
# w_bw {'X': 664, 'Y': 1492}
# w_gy1 {'X': 1184, 'Y': 1445}
# w_gy2 {'X': 2000, 'Y': 954}
# w_rc {'X': 1491, 'Y': 1352}
# w_rs {'X': 1646, 'Y': 947}
# w_rt {'X': 926, 'Y': 1490}
# w_tt {'X': 550, 'Y': 1522}
# y_gy1 {'X': 1258, 'Y': 1558}
# y_gy2 {'X': 1939, 'Y': 1182}
# y_rc {'X': 1429, 'Y': 1491}
# y_rh {'X': 717, 'Y': 1852}
# y_rs {'X': 1805, 'Y': 1246}
# y_rt {'X': 977, 'Y': 1666}

# %% [markdown]
# Si anallizamos la última fila de la lista de nodos podemos ver:

# %%
# Ejemplo de lista de nodos
print(fila_nodo)
# Out:
# id    y_rt
# X      977
# Y     1666
# Name: 76, dtype: object

# %% [markdown]
# ## 3. Explorando el grafo creado
#
# El grafo creado almacena la información de cada arco en una tupla de tres elementos. Dos son string y el tercero es un diccionario.

# %%
# Visualizar el grafo
#g.edges.data()

# Listar la información de las aristas (arcos)
for arc in g.edges.data():
  print(arc)
# Out:
# ('rs_end_north', 'v_rs', {'attr_dict': {'trail': 'rs', 'distance': 0.3, 'color': 'red', 'estimate': 0}})
# ('v_rs', 'b_rs', {'attr_dict': {'trail': 'rs', 'distance': 0.21, 'color': 'red', 'estimate': 0}})
# ('v_rs', 'v_bv', {'attr_dict': {'trail': 'v', 'distance': 0.52, 'color': 'violet', 'estimate': 0}})
# ('v_rs', 'v_end_east', {'attr_dict': {'trail': 'v', 'distance': 0.54, 'color': 'violet', 'estimate': 0}})
# ('b_rs', 'g_rs', {'attr_dict': {'trail': 'rs', 'distance': 0.11, 'color': 'red', 'estimate': 0}})
# ('b_rs', 'b_bv', {'attr_dict': {'trail': 'b', 'distance': 0.43, 'color': 'blue', 'estimate': 0}})
# ('b_rs', 'b_g', {'attr_dict': {'trail': 'b', 'distance': 0.07, 'color': 'blue', 'estimate': 0}})
# ('g_rs', 'w_rs', {'attr_dict': {'trail': 'rs', 'distance': 0.18, 'color': 'red', 'estimate': 0}})
# ('g_rs', 'g_rc', {'attr_dict': {'trail': 'g', 'distance': 0.45, 'color': 'green', 'estimate': 0}})
# ('g_rs', 'b_g', {'attr_dict': {'trail': 'g', 'distance': 0.05, 'color': 'green', 'estimate': 1}})
# ('w_rs', 'o_rs', {'attr_dict': {'trail': 'rs', 'distance': 0.21, 'color': 'red', 'estimate': 0}})
# ('w_rs', 'o_w_2', {'attr_dict': {'trail': 'w', 'distance': 0.26, 'color': 'gray', 'estimate': 0}})
# ('w_rs', 'b_w', {'attr_dict': {'trail': 'w', 'distance': 0.06, 'color': 'gray', 'estimate': 1}})
# ('o_rs', 'y_rs', {'attr_dict': {'trail': 'rs', 'distance': 0.12, 'color': 'red', 'estimate': 0}})
# ('o_rs', 'o_w_2', {'attr_dict': {'trail': 'o', 'distance': 0.15, 'color': 'orange', 'estimate': 0}})
# ('o_rs', 'o_gy2', {'attr_dict': {'trail': 'o', 'distance': 0.33, 'color': 'orange', 'estimate': 0}})
# ('y_rs', 'rs_end_south', {'attr_dict': {'trail': 'rs', 'distance': 0.39, 'color': 'red', 'estimate': 0}})
# ('y_rs', 'y_rc', {'attr_dict': {'trail': 'y', 'distance': 0.53, 'color': 'yellow', 'estimate': 0}})
# ('y_rs', 'y_gy2', {'attr_dict': {'trail': 'y', 'distance': 0.16, 'color': 'yellow', 'estimate': 0}})
# ('rc_end_north', 'v_rc', {'attr_dict': {'trail': 'rc', 'distance': 0.7, 'color': 'red', 'estimate': 0}})
# ('v_rc', 'b_rc', {'attr_dict': {'trail': 'rc', 'distance': 0.04, 'color': 'red', 'estimate': 0}})
# ('v_rc', 'v_rt', {'attr_dict': {'trail': 'v', 'distance': 0.5, 'color': 'violet', 'estimate': 0}})
# ('v_rc', 'v_bv', {'attr_dict': {'trail': 'v', 'distance': 0.27, 'color': 'violet', 'estimate': 0}})
# ('b_rc', 'g_rc', {'attr_dict': {'trail': 'rc', 'distance': 0.15, 'color': 'red', 'estimate': 0}})
# ('b_rc', 'b_tt_3', {'attr_dict': {'trail': 'b', 'distance': 0.4, 'color': 'blue', 'estimate': 0}})
# ('b_rc', 'b_bv', {'attr_dict': {'trail': 'b', 'distance': 0.41, 'color': 'blue', 'estimate': 0}})
# ('g_rc', 'o_rc', {'attr_dict': {'trail': 'rc', 'distance': 0.13, 'color': 'red', 'estimate': 0}})
# ('g_rc', 'g_gy1', {'attr_dict': {'trail': 'g', 'distance': 0.37, 'color': 'green', 'estimate': 0}})
# ('o_rc', 'w_rc', {'attr_dict': {'trail': 'rc', 'distance': 0.23, 'color': 'red', 'estimate': 1}})
# ('o_rc', 'o_gy1', {'attr_dict': {'trail': 'o', 'distance': 0.58, 'color': 'orange', 'estimate': 0}})
# ('o_rc', 'o_w_2', {'attr_dict': {'trail': 'o', 'distance': 0.11, 'color': 'orange', 'estimate': 0}})
# ('w_rc', 'y_rc', {'attr_dict': {'trail': 'rc', 'distance': 0.14, 'color': 'red', 'estimate': 0}})
# ('w_rc', 'w_gy1', {'attr_dict': {'trail': 'w', 'distance': 0.33, 'color': 'gray', 'estimate': 0}})
# ('w_rc', 'o_w_2', {'attr_dict': {'trail': 'w', 'distance': 0.23, 'color': 'gray', 'estimate': 0}})
# ('y_rc', 'rc_end_south', {'attr_dict': {'trail': 'rc', 'distance': 0.36, 'color': 'red', 'estimate': 0}})
# ('y_rc', 'y_gy1', {'attr_dict': {'trail': 'y', 'distance': 0.18, 'color': 'yellow', 'estimate': 0}})
# ('rt_end_north', 'v_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.3, 'color': 'red', 'estimate': 0}})
# ('v_rt', 'tt_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.16, 'color': 'red', 'estimate': 0}})
# ('v_rt', 'v_rh', {'attr_dict': {'trail': 'v', 'distance': 0.44, 'color': 'violet', 'estimate': 0}})
# ('tt_rt', 'b_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.04, 'color': 'red', 'estimate': 1}})
# ('tt_rt', 'b_tt_1', {'attr_dict': {'trail': 'tt', 'distance': 0.36, 'color': 'black', 'estimate': 0}})
# ('tt_rt', 'b_tt_2', {'attr_dict': {'trail': 'tt', 'distance': 0.06, 'color': 'black', 'estimate': 1}})
# ('b_rt', 'g_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.09, 'color': 'red', 'estimate': 0}})
# ('b_rt', 'b_bw', {'attr_dict': {'trail': 'b', 'distance': 0.14, 'color': 'blue', 'estimate': 0}})
# ('b_rt', 'b_tt_2', {'attr_dict': {'trail': 'b', 'distance': 0.03, 'color': 'blue', 'estimate': 1}})
# ('g_rt', 'o_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.05, 'color': 'red', 'estimate': 1}})
# ('g_rt', 'g_w', {'attr_dict': {'trail': 'g', 'distance': 0.31, 'color': 'green', 'estimate': 0}})
# ('g_rt', 'g_gy1', {'attr_dict': {'trail': 'g', 'distance': 0.26, 'color': 'green', 'estimate': 0}})
# ('o_rt', 'w_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.06, 'color': 'red', 'estimate': 0}})
# ('o_rt', 'o_w_1', {'attr_dict': {'trail': 'o', 'distance': 0.13, 'color': 'orange', 'estimate': 0}})
# ('w_rt', 'y_rt', {'attr_dict': {'trail': 'rt', 'distance': 0.19, 'color': 'red', 'estimate': 0}})
# ('w_rt', 'o_w_1', {'attr_dict': {'trail': 'w', 'distance': 0.09, 'color': 'gray', 'estimate': 0}})
# ('w_rt', 'w_gy1', {'attr_dict': {'trail': 'w', 'distance': 0.33, 'color': 'gray', 'estimate': 0}})
# ('y_rt', 'rt_end_south', {'attr_dict': {'trail': 'rt', 'distance': 0.18, 'color': 'red', 'estimate': 0}})
# ('y_rt', 'y_rh', {'attr_dict': {'trail': 'y', 'distance': 0.32, 'color': 'yellow', 'estimate': 0}})
# ('y_rt', 'y_gy1', {'attr_dict': {'trail': 'y', 'distance': 0.31, 'color': 'yellow', 'estimate': 0}})
# ('y_rt', 'o_tt', {'attr_dict': {'trail': 'nature', 'distance': 0.35, 'color': 'forestgreen', 'estimate': 0}})
# ('rh_end_north', 'v_rh', {'attr_dict': {'trail': 'rh', 'distance': 0.24, 'color': 'red', 'estimate': 0}})
# ('v_rh', 'b_rh', {'attr_dict': {'trail': 'rh', 'distance': 0.12, 'color': 'red', 'estimate': 0}})
# ('v_rh', 'v_rd', {'attr_dict': {'trail': 'v', 'distance': 0.38, 'color': 'violet', 'estimate': 0}})
# ('b_rh', 'rh_end_tt_1', {'attr_dict': {'trail': 'rh', 'distance': 0.06, 'color': 'red', 'estimate': 0}})
# ('b_rh', 'b_rd', {'attr_dict': {'trail': 'b', 'distance': 0.53, 'color': 'blue', 'estimate': 0}})
# ('b_rh', 'b_tt_1', {'attr_dict': {'trail': 'b', 'distance': 0.06, 'color': 'blue', 'estimate': 0}})
# ('rh_end_tt_1', 'w_tt', {'attr_dict': {'trail': 'tt', 'distance': 0.08, 'color': 'black', 'estimate': 0}})
# ('rh_end_tt_1', 'b_tt_1', {'attr_dict': {'trail': 'tt', 'distance': 0.03, 'color': 'black', 'estimate': 1}})
# ('rh_end_tt_2', 'o_rh', {'attr_dict': {'trail': 'rh', 'distance': 0.07, 'color': 'red', 'estimate': 1}})
# ('rh_end_tt_2', 'o_tt', {'attr_dict': {'trail': 'tt', 'distance': 0.13, 'color': 'black', 'estimate': 0}})
# ('rh_end_tt_2', 'w_tt', {'attr_dict': {'trail': 'tt', 'distance': 0.06, 'color': 'black', 'estimate': 1}})
# ('o_rh', 'rh_end_tt_3', {'attr_dict': {'trail': 'rh', 'distance': 0.04, 'color': 'red', 'estimate': 1}})
# ('o_rh', 'o_y_tt_end_west', {'attr_dict': {'trail': 'o', 'distance': 0.32, 'color': 'orange', 'estimate': 0}})
# ('o_rh', 'o_tt', {'attr_dict': {'trail': 'o', 'distance': 0.08, 'color': 'orange', 'estimate': 1}})
# ('rh_end_tt_3', 'rh_end_tt_4', {'attr_dict': {'trail': 'tt', 'distance': 0.15, 'color': 'black', 'estimate': 1}})
# ('rh_end_tt_3', 'o_tt', {'attr_dict': {'trail': 'tt', 'distance': 0.11, 'color': 'black', 'estimate': 1}})
# ('rh_end_tt_4', 'y_rh', {'attr_dict': {'trail': 'rh', 'distance': 0.09, 'color': 'red', 'estimate': 0}})
# ('rh_end_tt_4', 'nature_end_west', {'attr_dict': {'trail': 'tt', 'distance': 0.2, 'color': 'black', 'estimate': 0}})
# ('y_rh', 'rh_end_south', {'attr_dict': {'trail': 'rh', 'distance': 0.06, 'color': 'red', 'estimate': 0}})
# ('y_rh', 'o_y_tt_end_west', {'attr_dict': {'trail': 'y', 'distance': 0.26, 'color': 'yellow', 'estimate': 0}})
# ('y_rh', 'nature_end_west', {'attr_dict': {'trail': 'nature', 'distance': 0.11, 'color': 'forestgreen', 'estimate': 0}})
# ('rd_end_north', 'v_rd', {'attr_dict': {'trail': 'rd', 'distance': 0.14, 'color': 'red', 'estimate': 0}})
# ('v_rd', 'b_rd', {'attr_dict': {'trail': 'rd', 'distance': 0.06, 'color': 'red', 'estimate': 1}})
# ('v_rd', 'b_v', {'attr_dict': {'trail': 'v', 'distance': 0.3, 'color': 'violet', 'estimate': 0}})
# ('b_rd', 'rd_end_south', {'attr_dict': {'trail': 'rd', 'distance': 0.13, 'color': 'red', 'estimate': 0}})
# ('b_rd', 'b_rd_dupe', {'attr_dict': {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}})
# ('rd_end_south', 'b_v', {'attr_dict': {'trail': 'b', 'distance': 0.04, 'color': 'blue', 'estimate': 1}})
# ('rd_end_south', 'rd_end_south_dupe', {'attr_dict': {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}})
# ('v_end_west', 'b_v', {'attr_dict': {'trail': 'v', 'distance': 0.13, 'color': 'violet', 'estimate': 0}})
# ('b_v', 'bstub_w', {'attr_dict': {'trail': 'b', 'distance': 0.1, 'color': 'blue', 'estimate': 0}})
# ('b_v', 'b_end_west', {'attr_dict': {'trail': 'b', 'distance': 0.32, 'color': 'blue', 'estimate': 0}})
# ('v_bv', 'b_bv', {'attr_dict': {'trail': 'bv', 'distance': 0.08, 'color': 'purple', 'estimate': 0}})
# ('bstub_w', 'w_tt', {'attr_dict': {'trail': 'w', 'distance': 0.38, 'color': 'gray', 'estimate': 0}})
# ('rd_end_south_dupe', 'b_rd_dupe', {'attr_dict': {'trail': 'b', 'distance': 0.16, 'color': 'blue', 'estimate': 0}})
# ('b_tt_1', 'b_bw', {'attr_dict': {'trail': 'b', 'distance': 0.18, 'color': 'blue', 'estimate': 0}})
# ('b_bw', 'w_bw', {'attr_dict': {'trail': 'bw', 'distance': 0.19, 'color': 'lightblue', 'estimate': 0}})
# ('b_tt_2', 'b_tt_3', {'attr_dict': {'trail': 'b', 'distance': 0.15, 'color': 'blue', 'estimate': 0}})
# ('b_tt_2', 'b_tt_2_dupe', {'attr_dict': {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}})
# ('b_tt_3', 'b_tt_3_dupe', {'attr_dict': {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}})
# ('b_g', 'b_w', {'attr_dict': {'trail': 'b', 'distance': 0.16, 'color': 'blue', 'estimate': 0}})
# ('b_g', 'g_gy2', {'attr_dict': {'trail': 'g', 'distance': 0.45, 'color': 'green', 'estimate': 0}})
# ('b_w', 'b_gy2', {'attr_dict': {'trail': 'b', 'distance': 0.41, 'color': 'blue', 'estimate': 0}})
# ('b_w', 'w_gy2', {'attr_dict': {'trail': 'w', 'distance': 0.42, 'color': 'gray', 'estimate': 0}})
# ('b_gy2', 'b_o', {'attr_dict': {'trail': 'b', 'distance': 0.05, 'color': 'blue', 'estimate': 1}})
# ('b_gy2', 'w_gy2', {'attr_dict': {'trail': 'gy2', 'distance': 0.03, 'color': 'yellowgreen', 'estimate': 1}})
# ('b_gy2', 'o_gy2', {'attr_dict': {'trail': 'gy2', 'distance': 0.07, 'color': 'yellowgreen', 'estimate': 0}})
# ('b_o', 'b_y', {'attr_dict': {'trail': 'b', 'distance': 0.08, 'color': 'blue', 'estimate': 0}})
# ('b_o', 'o_gy2', {'attr_dict': {'trail': 'o', 'distance': 0.06, 'color': 'orange', 'estimate': 0}})
# ('b_o', 'park_east', {'attr_dict': {'trail': 'o', 'distance': 0.11, 'color': 'orange', 'estimate': 0}})
# ('b_y', 'b_end_east', {'attr_dict': {'trail': 'b', 'distance': 1.32, 'color': 'blue', 'estimate': 0}})
# ('b_y', 'y_gy2', {'attr_dict': {'trail': 'y', 'distance': 0.28, 'color': 'yellow', 'estimate': 0}})
# ('b_y', 'park_east', {'attr_dict': {'trail': 'y', 'distance': 0.14, 'color': 'yellow', 'estimate': 0}})
# ('w_tt', 'w_bw', {'attr_dict': {'trail': 'w', 'distance': 0.24, 'color': 'gray', 'estimate': 0}})
# ('w_bw', 'g_w', {'attr_dict': {'trail': 'w', 'distance': 0.09, 'color': 'gray', 'estimate': 0}})
# ('g_w', 'o_w_1', {'attr_dict': {'trail': 'w', 'distance': 0.18, 'color': 'gray', 'estimate': 0}})
# ('o_w_1', 'o_tt', {'attr_dict': {'trail': 'o', 'distance': 0.27, 'color': 'orange', 'estimate': 0}})
# ('o_w_1', 'o_gy1', {'attr_dict': {'trail': 'o', 'distance': 0.24, 'color': 'orange', 'estimate': 0}})
# ('w_gy1', 'o_gy1', {'attr_dict': {'trail': 'gy1', 'distance': 0.16, 'color': 'yellowgreen', 'estimate': 0}})
# ('w_gy1', 'y_gy1', {'attr_dict': {'trail': 'gy1', 'distance': 0.14, 'color': 'yellowgreen', 'estimate': 0}})
# ('w_gy2', 'park_east', {'attr_dict': {'trail': 'w', 'distance': 0.12, 'color': 'gray', 'estimate': 0}})
# ('w_gy2', 'g_gy2', {'attr_dict': {'trail': 'gy2', 'distance': 0.05, 'color': 'yellowgreen', 'estimate': 0}})
# ('park_east', 'g_gy2', {'attr_dict': {'trail': 'g', 'distance': 0.14, 'color': 'green', 'estimate': 0}})
# ('g_gy1', 'o_gy1', {'attr_dict': {'trail': 'gy1', 'distance': 0.15, 'color': 'yellowgreen', 'estimate': 0}})
# ('o_y_tt_end_west', 'nature_end_west', {'attr_dict': {'trail': 'tt', 'distance': 0.16, 'color': 'black', 'estimate': 0}})
# ('o_gy2', 'y_gy2', {'attr_dict': {'trail': 'gy2', 'distance': 0.12, 'color': 'yellowgreen', 'estimate': 0}})
# ('b_tt_2_dupe', 'b_tt_3_dupe', {'attr_dict': {'trail': 'tt', 'distance': 0.18, 'color': 'black', 'estimate': 0}})

# %% [markdown]
# ### Imprimir los primeros cinco arcos

# %%
# Visualizar los primeros cinco arcos del grafo
list(g.edges(data=True))[:5]
# Out:
# [('rs_end_north',
#   'v_rs',
#   {'attr_dict': {'trail': 'rs',
#     'distance': 0.3,
#     'color': 'red',
#     'estimate': 0}}),
#  ('v_rs',
#   'b_rs',
#   {'attr_dict': {'trail': 'rs',
#     'distance': 0.21,
#     'color': 'red',
#     'estimate': 0}}),
#  ('v_rs',
#   'v_bv',
#   {'attr_dict': {'trail': 'v',
#     'distance': 0.52,
#     'color': 'violet',
#     'estimate': 0}}),
#  ('v_rs',
#   'v_end_east',
#   {'attr_dict': {'trail': 'v',
#     'distance': 0.54,
#     'color': 'violet',
#     'estimate': 0}}),
#  ('b_rs',
#   'g_rs',
#   {'attr_dict': {'trail': 'rs',
#     'distance': 0.11,
#     'color': 'red',
#     'estimate': 0}})]

# %% [markdown]
# También podemos visualizar la información de los nodos:

# %%
# Visualizar los 10 primeros nodos
list(g.nodes(data=True))
# Out:
# [('rs_end_north', {'X': 1772, 'Y': 172}),
#  ('v_rs', {'X': 1793, 'Y': 484}),
#  ('b_rs', {'X': 1747, 'Y': 700}),
#  ('g_rs', {'X': 1676, 'Y': 775}),
#  ('w_rs', {'X': 1646, 'Y': 947}),
#  ('o_rs', {'X': 1724, 'Y': 1148}),
#  ('y_rs', {'X': 1805, 'Y': 1246}),
#  ('rs_end_south', {'X': 1865, 'Y': 1598}),
#  ('rc_end_north', {'X': 867, 'Y': 618}),
#  ('v_rc', {'X': 1288, 'Y': 934}),
#  ('b_rc', {'X': 1311, 'Y': 979}),
#  ('g_rc', {'X': 1451, 'Y': 1020}),
#  ('o_rc', {'X': 1498, 'Y': 1153}),
#  ('w_rc', {'X': 1491, 'Y': 1352}),
#  ('y_rc', {'X': 1429, 'Y': 1491}),
#  ('rc_end_south', {'X': 1450, 'Y': 1800}),
#  ('rt_end_north', {'X': 681, 'Y': 850}),
#  ('v_rt', {'X': 802, 'Y': 1115}),
#  ('tt_rt', {'X': 833, 'Y': 1273}),
#  ('b_rt', {'X': 835, 'Y': 1309}),
#  ('g_rt', {'X': 908, 'Y': 1378}),
#  ('o_rt', {'X': 927, 'Y': 1427}),
#  ('w_rt', {'X': 926, 'Y': 1490}),
#  ('y_rt', {'X': 977, 'Y': 1666}),
#  ('rt_end_south', {'X': 944, 'Y': 1837}),
#  ('rh_end_north', {'X': 205, 'Y': 1472}),
#  ('v_rh', {'X': 415, 'Y': 1350}),
#  ('b_rh', {'X': 525, 'Y': 1380}),
#  ('rh_end_tt_1', {'X': 558, 'Y': 1430}),
#  ('rh_end_tt_2', {'X': 550, 'Y': 1608}),
#  ('o_rh', {'X': 585, 'Y': 1674}),
#  ('rh_end_tt_3', {'X': 573, 'Y': 1707}),
#  ('rh_end_tt_4', {'X': 695, 'Y': 1767}),
#  ('y_rh', {'X': 717, 'Y': 1852}),
#  ('rh_end_south', {'X': 721, 'Y': 1925}),
#  ('rd_end_north', {'X': 185, 'Y': 1561}),
#  ('v_rd', {'X': 258, 'Y': 1684}),
#  ('b_rd', {'X': 268, 'Y': 1744}),
#  ('rd_end_south', {'X': 273, 'Y': 1869}),
#  ('v_end_west', {'X': 359, 'Y': 1976}),
#  ('b_v', {'X': 285, 'Y': 1937}),
#  ('v_bv', {'X': 1425, 'Y': 691}),
#  ('v_end_east', {'X': 2131, 'Y': 921}),
#  ('bstub_w', {'X': 372, 'Y': 1845}),
#  ('b_end_west', {'X': 141, 'Y': 1938}),
#  ('rd_end_south_dupe', {'X': 273, 'Y': 1869}),
#  ('b_rd_dupe', {'X': 268, 'Y': 1744}),
#  ('b_tt_1', {'X': 571, 'Y': 1418}),
#  ('b_bw', {'X': 716, 'Y': 1357}),
#  ('b_tt_2', {'X': 857, 'Y': 1287}),
#  ('b_tt_3', {'X': 1006, 'Y': 1206}),
#  ('b_bv', {'X': 1486, 'Y': 732}),
#  ('b_g', {'X': 1725, 'Y': 771}),
#  ('b_w', {'X': 1691, 'Y': 940}),
#  ('b_gy2', {'X': 2000, 'Y': 983}),
#  ('b_o', {'X': 2039, 'Y': 1012}),
#  ('b_y', {'X': 2134, 'Y': 1078}),
#  ('b_end_east', {'X': 3164, 'Y': 1111}),
#  ('w_tt', {'X': 550, 'Y': 1522}),
#  ('w_bw', {'X': 664, 'Y': 1492}),
#  ('g_w', {'X': 700, 'Y': 1582}),
#  ('o_w_1', {'X': 850, 'Y': 1490}),
#  ('w_gy1', {'X': 1184, 'Y': 1445}),
#  ('o_w_2', {'X': 1600, 'Y': 1176}),
#  ('w_gy2', {'X': 2000, 'Y': 954}),
#  ('park_east', {'X': 2131, 'Y': 921}),
#  ('g_gy1', {'X': 1098, 'Y': 1183}),
#  ('g_gy2', {'X': 1976, 'Y': 906}),
#  ('o_y_tt_end_west', {'X': 459, 'Y': 1924}),
#  ('o_tt', {'X': 665, 'Y': 1690}),
#  ('o_gy1', {'X': 1130, 'Y': 1297}),
#  ('o_gy2', {'X': 1994, 'Y': 1059}),
#  ('y_gy1', {'X': 1258, 'Y': 1558}),
#  ('y_gy2', {'X': 1939, 'Y': 1182}),
#  ('nature_end_west', {'X': 600, 'Y': 1861}),
#  ('b_tt_2_dupe', {'X': 857, 'Y': 1287}),
#  ('b_tt_3_dupe', {'X': 1006, 'Y': 1206})]

# %% [markdown]
# ### Estadísticas del grafo
#
# También se pueden imprimir algunas valores que resumen los elementos del grafo.

# %%
print(f'Número de arcos: {g.number_of_edges()}')
print(f'Número de nodos: {g.number_of_nodes()}')
# Out:
# Número de arcos: 123
# Número de nodos: 77

# %% [markdown]
# ## 4. Visualización del grafo
#
# Primero hay que manipular las posiciones de los nodos del gráfico en un diccionario. Esto te permitirá recrear el gráfico usando la misma disposición que el mapa de senderos real. **Y** se anula para transformar el origen del eje Y de la parte superior izquierda a la inferior izquierda.

# %%
# Defino las posiciones del nodo de la estructura de datos (dict) para graficarlo
node_positions = {node[0]: (node[1]['X'], -node[1]['Y']) for node in g.nodes(data=True)}

# Previsualización node_positions 
print(dict(list(node_positions.items())[0:5]))
node_new_colors = dict(list(node_positions.items())[0:5])
print(node_new_colors)
# Out:
# {'rs_end_north': (1772, -172), 'v_rs': (1793, -484), 'b_rs': (1747, -700), 'g_rs': (1676, -775), 'w_rs': (1646, -947)}
# {'rs_end_north': (1772, -172), 'v_rs': (1793, -484), 'b_rs': (1747, -700), 'g_rs': (1676, -775), 'w_rs': (1646, -947)}

# %% [markdown]
# **Colores**: Ahora configuraremos los colores de los arcos del gráfico en una simple lista para se pueda visualizar los caminos (senderos) por su color.

# %%
# Definir una estructura de datos (list) para los colores de los arcos en el gráfico
edge_colors = [data['attr_dict']['color'] for _, _, data in g.edges(data=True)]

#print(edge_colors)

# Preview first 10
edge_colors[0:20]
# Out:
# ['red',
#  'red',
#  'violet',
#  'violet',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'green',
#  'green',
#  'red',
#  'gray',
#  'gray',
#  'red',
#  'orange',
#  'orange',
#  'red',
#  'yellow',
#  'yellow',
#  'red']

# %% [markdown]
# ## 5. Graficar
#
# Ahora puedes hacer un buen gráfico que se alinee bien con el mapa de senderos del parque Sleeping Giant.

# %%
list(g.edges(data=True))[0]
# Out:
# ('rs_end_north',
#  'v_rs',
#  {'attr_dict': {'trail': 'rs',
#    'distance': 0.3,
#    'color': 'red',
#    'estimate': 0}})

# %%
edge_colors = [data['attr_dict']['color'] for _, _, data in g.edges(data=True)]

# %%
plt.figure(figsize=(15, 11))
nx.draw(g, pos=node_positions, edge_color="grey", node_size=40, node_color='black')
plt.title('Grafo que representa los senderos de Sleeping Giant', size=15)
plt.xlabel('Posición X')
plt.ylabel('Posición Y')
plt.show()

# %% [markdown]
# Se puede visualizar el grafo de diferentes formas dependiendo de los parámetros que le pasemos al método `draw`.

# %%
plt.figure(figsize=(20, 10))
nx.draw(g, pos=node_positions, edge_color=edge_colors, node_size=30, node_color='black', with_labels = True)
plt.title('Grafo que representa los senderos de Sleeping Giant', size=20)
plt.axis('on')
plt.xlabel('Posición X')
plt.ylabel('Posición Y')
# Out:
# Text(0, 0.5, 'Posición Y')

# %% [markdown]
# # Tarea
#
# Resolver los siguientes ejercicios (**comente el código adecuadamente y explique brevemente que hace**)
#
# 1. Dibujar el grafo con aristas grises y un alfa=0.4. Dibujar de color rojo todos los nodos que tengan un número de senderos de entrada o salida impar.

# %%
def count_trails(node_id):
    count = 0;
    for n in list(g.edges(data=True)):
        if(n[0] == node_id or n[1] == node_id):
            count+= 1
    return count
print(count_trails(''))
# Out:
# 0

# %%
#FUNCIONES AUXILIARES 

#Función para contar senderos dado el id de un nodo
def count_trails(node_id):
    count = 0;
    for n in list(g.edges(data=True)):
        if(n[0] == node_id or n[1] == node_id):
            count+= 1
    return count

#Función para verificar paridad dado un número 
def isPair(x):
    if x % 2 == 0:
        return True
    else:
        return False

# %%
# Comentarios y código

#Si la cantidad de senderos del nodo no es par (impar), se coloreará rojo, sino negro.
color_map = ['red' if not isPair(count_trails(node)) else 'black' for node in g]

plt.figure(figsize=(50, 40))
nx.draw_networkx(g,node_positions,edge_color="grey", alpha=0.4, node_size=1000,  node_color=color_map)

# %% [markdown]
# 2.  Dibujar el grafo con aristas grises y un alfa=0.4. Dibujar de color azul todos los nodos que tengan un número de senderos de entrada o salida par.

# %%
# Comentarios y código

#Si la cantidad de senderos del nodo es par, se coloreará azul, sino negro.
color_map = ['blue' if isPair(count_trails(node)) else 'black' for node in g]

plt.figure(figsize=(50, 40))
nx.draw_networkx(g,node_positions, edge_color="grey", alpha=0.4, node_size=1000,  node_color=color_map)

# %% [markdown]
# 3. Dibujar el grafo con aristas grises y un alfa=0.4. Dibujar de color rojo todos los nodos que tengan un número de senderos de entrada o salida impar y de color azul los que tengan nodos par.

# %%
# Comentarios y código

#Si la cantidad de senderos del nodo es par, se coloreará azul, sino negro.
color_map = ['blue' if isPair(count_trails(node)) else 'red' for node in g]

plt.figure(figsize=(50, 40))
nx.draw_networkx(g,node_positions, edge_color="grey", alpha=0.4, node_size=1000,  node_color=color_map)

# %% [markdown]
# 4. Pintar los nodos de grado menor con colores claros y los nodo de grado mayor con tonos fuertes (use una paleta de gradientes).

# %%
# Comentarios y código

#Si la cantidad de senderos del nodo es par, se coloreará azul, sino negro.
color_map = [count_trails(node) for node in g]

plt.figure(figsize=(50, 40))
nx.draw_networkx(g,node_positions, edge_color="grey", node_size=1000,  node_color=color_map, cmap=plt.cm.Blues)

# %% [raw]
# # 5. Encontrar el camino más corto entre rc_end_north y rs_end_south. Dibujar la ruta en el grafo. Donde los arcos rojos representen la ruta mínima y los grises las rutas que no son visitadas. Los arcos que son visitados colocar la distacia.

# %%
route=[]
distances = []


def get_min(node):
    
    print(node)
    #lista auxiliar
    options = []
    next_node = node
    min_dist = 9999

    for n in list(g.edges(data=True)):
        if(n[0] == node or n[1] == node):
            if(n[2]['attr_dict']['distance']< min_dist):
                if n[0] == node:
                    next_node = n[1]
                    if (route.count(next_node)<1):
                        min_dist = n[2]['attr_dict']['distance']
                else:
                    next_node = n[0]
                    if (route.count(next_node)<1):
                        min_dist = n[2]['attr_dict']['distance']
    return[next_node,min_dist]
    

def build_route(start_node, finish_node):
    route.append(start_node)
    
    print(get_min(start_node))
    next_node = get_min(start_node) 
    
    route.append(next_node[0])
    
    while next_node[0] != finish_node:
        route.append(next_node[0])
        next_node = get_min(next_node[0])
    print(route)
build_route('b_rc','v_bv')
# Out:
# b_rc
# ['v_rc', 0.04]
# b_rc
# v_rc
# ['b_rc', 'v_rc', 'v_rc']

# %% [markdown]
# 6. ¿Existen nodos que forman comunidades en el grafo?. Si es así, dibujar un grafo donde se muestren las comunidades. Arcos o rutas en rojo representan las comunidades conectadas y las grises nodos no conectados.

# %%
# Comentarios y código

# %% [markdown]
# 7. Pinte de color rojo, y aumente su tamaño a 40, dle nodo más importante y el resto de color negro.

# %%
# Comentarios y código

# %% [markdown]
# 8. Implemente un gráfico de barras donde el eje x indique el grado de un nodo y el eje y la frecuencia.

# %%
# Comentarios y código

# %% [markdown]
# 9. (Opcional) Aplique lo visto en clases con otro tipo de datos.

# %% [markdown]
# # Códigos de ejemplo

# %%
# Código de ejemplo
plt.figure(figsize=(12, 10))
nx.draw_networkx_nodes(g, node_positions, node_size=20, node_color="red")
# Visualizar los 10 primeros nodos
lista_nodos_verdes = [n[0] for n in list(g.nodes(data=True))[0:10]]
nx.draw_networkx_nodes(g, node_positions, nodelist=lista_nodos_verdes, node_size=60, node_color="green")

nx.draw_networkx_edges(g, node_positions, alpha=0.4)
plt.axis('on')
#plt.grid('on')
plt.title('Cambiando el color de los arcos del grafo')
plt.show()

# %%
from networkx.classes.function import nodes_with_selfloops
# Grado de un nodo
l = []
for nodo in g.degree():
  if nodo[1] == 1:
    print(nodo[0])
    l.append(nodo[0])
print(l)
