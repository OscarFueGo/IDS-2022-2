# %%
import networkx as nx # Librería para grafos
import pandas as pd # Librería para manejar datos (dataframe)
import matplotlib.pyplot as plt # Librería para gráficos

# %%
lista_arcos = pd.read_csv('https://gist.githubusercontent.com/brooksandrew/e570c38bcc72a8d102422f2af836513b/raw/89c76b2563dbc0e88384719a35cba0dfc04cd522/edgelist_sleeping_giant.csv')
lista_nodos = pd.read_csv('https://gist.githubusercontent.com/brooksandrew/f989e10af17fb4c85b11409fea47895b/raw/a3a8da0fa5b094f1ca9d82e1642b384889ae16e8/nodelist_sleeping_giant.csv')

# %%
lista_arcos.head()
# Out:
#           node1 node2 trail  distance color  estimate
# 0  rs_end_north  v_rs    rs      0.30   red         0
# 1          v_rs  b_rs    rs      0.21   red         0
# 2          b_rs  g_rs    rs      0.11   red         0
# 3          g_rs  w_rs    rs      0.18   red         0
# 4          w_rs  o_rs    rs      0.21   red         0

# %%
g= nx.Graph()
g.

# %%
for index, dato_arco in lista_arcos.iterrows():
    print(f'Indice {dato_arco["node1"]}')
# Out:
# Indice rs_end_north
# Indice v_rs
# Indice b_rs
# Indice g_rs
# Indice w_rs
# Indice o_rs
# Indice y_rs
# Indice rc_end_north
# Indice v_rc
# Indice b_rc
# Indice g_rc
# Indice o_rc
# Indice w_rc
# Indice y_rc
# Indice rt_end_north
# Indice v_rt
# Indice tt_rt
# Indice b_rt
# Indice g_rt
# Indice o_rt
# Indice w_rt
# Indice y_rt
# Indice rh_end_north
# Indice v_rh
# Indice b_rh
# Indice rh_end_tt_2
# Indice o_rh
# Indice rh_end_tt_4
# Indice y_rh
# Indice rd_end_north
# Indice v_rd
# Indice b_rd
# Indice v_end_west
# Indice b_v
# Indice v_rd
# Indice v_rh
# Indice v_rt
# Indice v_rc
# Indice v_bv
# Indice v_rs
# Indice bstub_w
# Indice b_end_west
# Indice b_v
# Indice rd_end_south_dupe
# Indice rd_end_south
# Indice b_rd
# Indice b_rd
# Indice b_rh
# Indice b_tt_1
# Indice b_bw
# Indice b_rt
# Indice b_tt_2
# Indice b_tt_3
# Indice b_rc
# Indice b_bv
# Indice b_rs
# Indice b_g
# Indice b_w
# Indice b_gy2
# Indice b_o
# Indice b_y
# Indice bstub_w
# Indice w_tt
# Indice w_bw
# Indice g_w
# Indice o_w_1
# Indice w_rt
# Indice w_gy1
# Indice w_rc
# Indice o_w_2
# Indice w_rs
# Indice b_w
# Indice w_gy2
# Indice g_w
# Indice g_rt
# Indice g_gy1
# Indice g_rc
# Indice g_rs
# Indice b_g
# Indice g_gy2
# Indice o_y_tt_end_west
# Indice o_rh
# Indice o_tt
# Indice o_w_1
# Indice o_w_1
# Indice o_gy1
# Indice o_rc
# Indice o_w_2
# Indice o_rs
# Indice o_gy2
# Indice b_o
# Indice o_y_tt_end_west
# Indice y_rh
# Indice y_rt
# Indice y_gy1
# Indice y_rc
# Indice y_rs
# Indice y_gy2
# Indice b_y
# Indice o_y_tt_end_west
# Indice nature_end_west
# Indice rh_end_tt_4
# Indice rh_end_tt_3
# Indice o_tt
# Indice rh_end_tt_2
# Indice w_tt
# Indice rh_end_tt_1
# Indice b_tt_1
# Indice tt_rt
# Indice b_tt_2_dupe
# Indice b_tt_3
# Indice b_tt_2
# Indice nature_end_west
# Indice o_tt
# Indice b_bw
# Indice g_gy1
# Indice o_gy1
# Indice w_gy1
# Indice v_bv
# Indice g_gy2
# Indice w_gy2
# Indice b_gy2
# Indice o_gy2
